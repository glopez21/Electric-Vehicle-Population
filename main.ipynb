# %% [markdown]
# <a href="https://colab.research.google.com/github/glopez21/Electric-Vehicle-Population/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Electric Vehicle Population

# %%
import numpy as np
# In this previous line I have imported the numpy library and I renamed it `np`
import pandas as pd
# In this line of code I have imported the pandas library and I renamed it `pd`

# %%
data = pd.read_csv('/content/drive/MyDrive/Projects/Electric Vehicle Population/Electric_Vehicle_Population_Data.csv')

# '/content/drive/MyDrive/Projects/Electric Vehicle Population/Electric_Vehicle_Population_Data.csv'


# In this line I created a variable named `data` and usinf pandas, I assigned to it the path to my data file.

# %%
data.head()
# IN this line I am using the pandas `head()` method to display the first 5 rown of my dataset.
# Out:
#    VIN (1-10)     County          City State  Postal Code  Model Year    Make  \
# 0  5YJ3E1EB5K     Yakima        Yakima    WA      98901.0        2019   TESLA
# 1  1C4RJXU67R     Kitsap  Port Orchard    WA      98367.0        2024    JEEP
# 2  KNDCD3LD0N  Snohomish      Lynnwood    WA      98036.0        2022     KIA
# 3  5UXKT0C37H       King        Auburn    WA      98001.0        2017     BMW
# 4  1N4AZ0CP1D     Skagit  Mount Vernon    WA      98273.0        2013  NISSAN
#
#       Model                   Electric Vehicle Type  \
# 0   MODEL 3          Battery Electric Vehicle (BEV)
# 1  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 2      NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 3        X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 4      LEAF          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible           220.0
# ...
